# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lci = pd.read_csv('lci_data_net.csv')
hague = pd.read_excel('Hague_cijfers.xlsx',sheet_name='Meest-recent')

# %%
hague = hague[['Naam van het gebied','Aantal inwoners']]
hague.columns = ['Name','Population']
lci = lci.merge(hague,on=['Name'],how='inner')
del lci['BUURTCODE']

# %%
lci['Energy'] = lci['Green_electricity']+ lci['nongreen_electricity'] + lci['Gas']
lci['Mobility'] = lci['Car'] + lci['Train'] + lci['bustram']
lci['BoP'] = lci['Clothes'] + lci['Furniture'] + lci['Paper']
lci = lci[['Name','Population','Food','Energy','Water','Mobility','BoP']]

# %%
resources = ['Food','Energy','Water','Mobility','BoP']
lci = lci[lci['Name'] != 'Binckhorst']
lci = lci.reset_index(drop=True)
for resource in resources:
    col = resource + '_normalized'
    mini = lci[resource].min()
    maxi = lci[resource].max()
    lci[col] = ((lci[resource]-mini)/(maxi-mini))
lci.head()
lci_norm = lci[['Food_normalized','Energy_normalized','Water_normalized','Mobility_normalized','BoP_normalized']]

# %%
lci_norm.index = lci['Name']
#lci_norm = lci_norm.drop(index=['Binckhorst'])
lci_norm.columns = ['Food','Energy','Water','Mobility','BoP']
lci_norm_food = lci_norm.sort_values(by=['Food'],ascending=False)
lci_norm_energy = lci_norm.sort_values(by=['Energy'],ascending=False)
lci_norm_water = lci_norm.sort_values(by=['Water'],ascending=False)
lci_norm_mobility = lci_norm.sort_values(by=['Mobility'],ascending=False)
lci_norm_BoP = lci_norm.sort_values(by=['BoP'],ascending=False)

# %%
f, axes = plt.subplots(3, 2,figsize=(11,9))
sns.heatmap(lci_norm_food.head(),cmap='viridis',ax=axes[0,0],cbar=False)
sns.heatmap(lci_norm_energy.head(),cmap='viridis',ax=axes[0,1],cbar=False)
sns.heatmap(lci_norm_water.head(),cmap='viridis',ax=axes[1,0],cbar=False)
sns.heatmap(lci_norm_mobility.head(),cmap='viridis',ax=axes[1,1],cbar=False)
sns.heatmap(lci_norm_BoP.head(),cmap='viridis',ax=axes[2,0],cbar=False)
#axes[2,0].legend(loc='right', bbox_to_anchor=(1.25, 0.5), ncol=1)
axes[0,0].set_title('Food')
axes[0,1].set_title('Energy')
axes[1,0].set_title('Water')
axes[1,1].set_title('Mobility')
axes[2,0].set_title('BoP')
axes[0,0].set_ylabel('')
axes[0,1].set_ylabel('')
axes[1,0].set_ylabel('')
axes[1,1].set_ylabel('')
axes[2,0].set_ylabel('')
f.delaxes(axes[2,1])
cbar = f.colorbar(axes[2,0], ax=axes.ravel().tolist(), shrink=0.95)
cbar.set_ticks(np.arange(0, 1.1, 0.5))
f.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-cbff43b9b4ec> in <module>
#      17 axes[2,0].set_ylabel('')
#      18 f.delaxes(axes[2,1])
# ---> 19 cbar = f.colorbar(axes[2,0], ax=axes.ravel().tolist(), shrink=0.95)
#      20 cbar.set_ticks(np.arange(0, 1.1, 0.5))
#      21 f.tight_layout()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2213                              'panchor']
#    2214         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2215         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2216
#    2217         self.sca(current_ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1638         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1639     else:
# -> 1640         cb = Colorbar(cax, mappable, **kwargs)
#    1641
#    1642     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colorbar.py in __init__(self, ax, mappable, **kw)
#    1156         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1157         # even if mappable.draw has not yet been called.
# -> 1158         if mappable.get_array() is not None:
#    1159             mappable.autoscale_None()
#    1160
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_array'

# %%
fig, axn = plt.subplots(3, 2,figsize=(11,9))
cbar_ax = fig.add_axes([1, .3, .03, .6])
df = [lci_norm_food,lci_norm_energy,lci_norm_water,lci_norm_mobility,lci_norm_BoP,lci_norm_food]
j = 0
fig.delaxes(axn[2,1])
for i, ax in enumerate(axn.flat):
    sns.heatmap(df[j].head(), ax=ax,
                cbar=i == 0,cmap='viridis',
                cbar_ax=None if i else cbar_ax)
    j = j + 1
axn[0,0].set_title('Food')
axn[0,1].set_title('Energy')
axn[1,0].set_title('Water')
axn[1,1].set_title('Mobility')
axn[2,0].set_title('BoP')
axn[0,0].set_ylabel('')
axn[0,1].set_ylabel('')
axn[1,0].set_ylabel('')
axn[1,1].set_ylabel('')
axn[2,0].set_ylabel('')
fig.tight_layout()
fig.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.savefig('heatmap.png',bbox_inches="tight")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# No handles with labels found to put in legend.
